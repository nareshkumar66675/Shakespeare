# %%
from pandas import DataFrame, read_csv

import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
spFilePath = r'C:\Users\kumar\OneDrive\Documents\Projects\Shakespeare\data\external\Shakespeare_data.csv'
spDF = pd.read_csv(spFilePath)
spDF
# Out:
#         Dataline            Play  PlayerLinenumber ActSceneLine  \
# 0              1        Henry IV               NaN          NaN
# 1              2        Henry IV               NaN          NaN
# 2              3        Henry IV               NaN          NaN
# 3              4        Henry IV               1.0        1.1.1
# 4              5        Henry IV               1.0        1.1.2
# 5              6        Henry IV               1.0        1.1.3
# 6              7        Henry IV               1.0        1.1.4
# 7              8        Henry IV               1.0        1.1.5
# 8              9        Henry IV               1.0        1.1.6
# 9             10        Henry IV               1.0        1.1.7
# 10            11        Henry IV               1.0        1.1.8
# 11            12        Henry IV               1.0        1.1.9
# 12            13        Henry IV               1.0       1.1.10
# 13            14        Henry IV               1.0       1.1.11
# 14            15        Henry IV               1.0       1.1.12
# 15            16        Henry IV               1.0       1.1.13
# 16            17        Henry IV               1.0       1.1.14
# 17            18        Henry IV               1.0       1.1.15
# 18            19        Henry IV               1.0       1.1.16
# 19            20        Henry IV               1.0       1.1.17
# 20            21        Henry IV               1.0       1.1.18
# 21            22        Henry IV               1.0       1.1.19
# 22            23        Henry IV               1.0       1.1.20
# 23            24        Henry IV               1.0       1.1.21
# 24            25        Henry IV               1.0       1.1.22
# 25            26        Henry IV               1.0       1.1.23
# 26            27        Henry IV               1.0       1.1.24
# 27            28        Henry IV               1.0       1.1.25
# 28            29        Henry IV               1.0       1.1.26
# 29            30        Henry IV               1.0       1.1.27
# ...          ...             ...               ...          ...
# 111366    111367  A Winters Tale              37.0      5.3.155
# 111367    111368  A Winters Tale              37.0      5.3.156
# 111368    111369  A Winters Tale              37.0      5.3.157
# 111369    111370  A Winters Tale              37.0      5.3.158
# 111370    111371  A Winters Tale              37.0      5.3.159
# 111371    111372  A Winters Tale              37.0      5.3.160
# 111372    111373  A Winters Tale              37.0      5.3.161
# 111373    111374  A Winters Tale              37.0      5.3.162
# 111374    111375  A Winters Tale              38.0      5.3.163
# 111375    111376  A Winters Tale              38.0      5.3.164
# 111376    111377  A Winters Tale              38.0      5.3.165
# 111377    111378  A Winters Tale              38.0      5.3.166
# 111378    111379  A Winters Tale              38.0      5.3.167
# 111379    111380  A Winters Tale              38.0      5.3.168
# 111380    111381  A Winters Tale              38.0      5.3.169
# 111381    111382  A Winters Tale              38.0      5.3.170
# 111382    111383  A Winters Tale              38.0      5.3.171
# 111383    111384  A Winters Tale              38.0      5.3.172
# 111384    111385  A Winters Tale              38.0      5.3.173
# 111385    111386  A Winters Tale              38.0      5.3.174
# 111386    111387  A Winters Tale              38.0      5.3.175
# 111387    111388  A Winters Tale              38.0      5.3.176
# 111388    111389  A Winters Tale              38.0      5.3.177
# 111389    111390  A Winters Tale              38.0      5.3.178
# 111390    111391  A Winters Tale              38.0      5.3.179
# 111391    111392  A Winters Tale              38.0      5.3.180
# 111392    111393  A Winters Tale              38.0      5.3.181
# 111393    111394  A Winters Tale              38.0      5.3.182
# 111394    111395  A Winters Tale              38.0      5.3.183
# 111395    111396  A Winters Tale              38.0          NaN
#
#                Player                                         PlayerLine
# 0                 NaN                                              ACT I
# 1                 NaN                       SCENE I. London. The palace.
# 2                 NaN  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3       KING HENRY IV             So shaken as we are, so wan with care,
# 4       KING HENRY IV         Find we a time for frighted peace to pant,
# 5       KING HENRY IV     And breathe short-winded accents of new broils
# 6       KING HENRY IV            To be commenced in strands afar remote.
# 7       KING HENRY IV          No more the thirsty entrance of this soil
# 8       KING HENRY IV  Shall daub her lips with her own children's bl...
# 9       KING HENRY IV   Nor more shall trenching war channel her fields,
# 10      KING HENRY IV      Nor bruise her flowerets with the armed hoofs
# 11      KING HENRY IV              Of hostile paces: those opposed eyes,
# 12      KING HENRY IV      Which, like the meteors of a troubled heaven,
# 13      KING HENRY IV          All of one nature, of one substance bred,
# 14      KING HENRY IV             Did lately meet in the intestine shock
# 15      KING HENRY IV                And furious close of civil butchery
# 16      KING HENRY IV         Shall now, in mutual well-beseeming ranks,
# 17      KING HENRY IV           March all one way and be no more opposed
# 18      KING HENRY IV          Against acquaintance, kindred and allies:
# 19      KING HENRY IV       The edge of war, like an ill-sheathed knife,
# 20      KING HENRY IV  No more shall cut his master. Therefore, friends,
# 21      KING HENRY IV              As far as to the sepulchre of Christ,
# 22      KING HENRY IV       Whose soldier now, under whose blessed cross
# 23      KING HENRY IV             We are impressed and engaged to fight,
# 24      KING HENRY IV        Forthwith a power of English shall we levy,
# 25      KING HENRY IV     Whose arms were moulded in their mothers' womb
# 26      KING HENRY IV         To chase these pagans in those holy fields
# 27      KING HENRY IV         Over whose acres walk'd those blessed feet
# 28      KING HENRY IV       Which fourteen hundred years ago were nail'd
# 29      KING HENRY IV             For our advantage on the bitter cross.
# ...               ...                                                ...
# 111366        PAULINA                      There's time enough for that,
# 111367        PAULINA         Lest they desire upon this push to trouble
# 111368        PAULINA         Your joys with like relation. Go together,
# 111369        PAULINA          You precious winners all, your exultation
# 111370        PAULINA            Partake to every one. I, an old turtle,
# 111371        PAULINA      Will wing me to some wither'd bough and there
# 111372        PAULINA           My mate, that's never to be found again,
# 111373        PAULINA                             Lament till I am lost.
# 111374        LEONTES                                 O, peace, Paulina!
# 111375        LEONTES        Thou shouldst a husband take by my consent,
# 111376        LEONTES             As I by thine a wife: this is a match,
# 111377        LEONTES  And made between's by vows. Thou hast found mine,
# 111378        LEONTES       But how, is to be question'd, for I saw her,
# 111379        LEONTES     As I thought, dead, and have in vain said many
# 111380        LEONTES       A prayer upon her grave. I'll not seek far--
# 111381        LEONTES      For him, I partly know his mind--to find thee
# 111382        LEONTES              An honourable husband. Come, Camillo,
# 111383        LEONTES  And take her by the hand, whose worth and honesty
# 111384        LEONTES                 Is richly noted and here justified
# 111385        LEONTES     By us, a pair of kings. Let's from this place.
# 111386        LEONTES     What! look upon my brother: both your pardons,
# 111387        LEONTES            That e'er I put between your holy looks
# 111388        LEONTES         My ill suspicion. This is your son-in-law,
# 111389        LEONTES     And son unto the king, who, heavens directing,
# 111390        LEONTES    Is troth-plight to your daughter. Good Paulina,
# 111391        LEONTES         Lead us from hence, where we may leisurely
# 111392        LEONTES              Each one demand an answer to his part
# 111393        LEONTES     Perform'd in this wide gap of time since first
# 111394        LEONTES             We were dissever'd: hastily lead away.
# 111395        LEONTES                                             Exeunt
#
# [111396 rows x 6 columns]

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %%
players = spDF.Player.unique()
i=0
labPly = dict()
for player in players:
    labPly[player]=i
    i=i+1

# %%
# Players and corresponding Labels
labPly
# Out:
# {nan: 0,
#  'KING HENRY IV': 1,
#  'WESTMORELAND': 2,
#  'FALSTAFF': 3,
#  'PRINCE HENRY': 4,
#  'POINS': 5,
#  'EARL OF WORCESTER': 6,
#  'NORTHUMBERLAND': 7,
#  'HOTSPUR': 8,
#  'SIR WALTER BLUNT': 9,
#  'First Carrier': 10,
#  'Ostler': 11,
#  'Second Carrier': 12,
#  'GADSHILL': 13,
#  'Chamberlain': 14,
#  'BARDOLPH': 15,
#  'PETO': 16,
#  'First Traveller': 17,
#  'Thieves': 18,
#  'Travellers': 19,
#  'LADY PERCY': 20,
#  'Servant': 21,
#  'FRANCIS': 22,
#  'Vintner': 23,
#  'Hostess': 24,
#  'Sheriff': 25,
#  'Carrier': 26,
#  'MORTIMER': 27,
#  'GLENDOWER': 28,
#  'EARL OF DOUGLAS': 29,
#  'Messenger': 30,
#  'VERNON': 31,
#  'WORCESTER': 32,
#  'ARCHBISHOP OF YORK': 33,
#  'SIR MICHAEL': 34,
#  'LANCASTER': 35,
#  'BEDFORD': 36,
#  'GLOUCESTER': 37,
#  'EXETER': 38,
#  'OF WINCHESTER': 39,
#  'CHARLES': 40,
#  'ALENCON': 41,
#  'REIGNIER': 42,
#  'BASTARD OF ORLEANS': 43,
#  'JOAN LA PUCELLE': 44,
#  'First Warder': 45,
#  'Second Warder': 46,
#  'WOODVILE': 47,
#  'Mayor': 48,
#  'Officer': 49,
#  'Boy': 50,
#  'SALISBURY': 51,
#  'TALBOT': 52,
#  'GARGRAVE': 53,
#  'GLANSDALE': 54,
#  'Sergeant': 55,
#  'First Sentinel': 56,
#  'BURGUNDY': 57,
#  'Sentinels': 58,
#  'Soldier': 59,
#  'Captain': 60,
#  'OF AUVERGNE': 61,
#  'Porter': 62,
#  'PLANTAGENET': 63,
#  'SUFFOLK': 64,
#  'SOMERSET': 65,
#  'WARWICK': 66,
#  'Lawyer': 67,
#  'First Gaoler': 68,
#  'KING HENRY VI': 69,
#  'ALL': 70,
#  'First Soldier': 71,
#  'Watch': 72,
#  'FASTOLFE': 73,
#  'BASSET': 74,
#  'YORK': 75,
#  'General': 76,
#  'LUCY': 77,
#  'JOHN TALBOT': 78,
#  'Legate': 79,
#  'Scout': 80,
#  'MARGARET': 81,
#  'SU FFOLK': 82,
#  'Shepherd': 83,
#  'QUEEN MARGARET': 84,
#  'CARDINAL': 85,
#  'BUCKINGHAM': 86,
#  'DUCHESS': 87,
#  'HUME': 88,
#  'First Petitioner': 89,
#  'Second Petitioner': 90,
#  'PETER': 91,
#  'HORNER': 92,
#  'BOLINGBROKE': 93,
#  'Spirit': 94,
#  'MARGARET JOURDAIN': 95,
#  'Townsman': 96,
#  'SIMPCOX': 97,
#  'Wife': 98,
#  'Beadle': 99,
#  'BOTH': 100,
#  'First Neighbour': 101,
#  'Second Neighbour': 102,
#  'Third Neighbour': 103,
#  'Servants': 104,
#  'Herald': 105,
#  'STANLEY': 106,
#  'Post': 107,
#  'First Murderer': 108,
#  'Second Murderer': 109,
#  'First Murder': 110,
#  'Commons': 111,
#  'VAUX': 112,
#  'First Gentleman': 113,
#  'Master': 114,
#  'Second Gentleman': 115,
#  'WHITMORE': 116,
#  'BEVIS': 117,
#  'HOLLAND': 118,
#  'CADE': 119,
#  'DICK': 120,
#  'SMITH': 121,
#  'Clerk': 122,
#  'CLERK': 123,
#  'MICHAEL': 124,
#  'SIR HUMPHREY': 125,
#  'WILLIAM STAFFORD': 126,
#  'SAY': 127,
#  'SCALES': 128,
#  'First Citizen': 129,
#  'CLIFFORD': 130,
#  'IDEN': 131,
#  'EDWARD': 132,
#  'RICHARD': 133,
#  'YOUNG CLIFFORD': 134,
#  'MONTAGUE': 135,
#  'NORFOLK': 136,
#  'PRINCE EDWARD': 137,
#  'JOHN MORTIMER': 138,
#  'RUTLAND': 139,
#  'Tutor': 140,
#  'PRINCE': 141,
#  'GEORGE': 142,
#  'Son': 143,
#  'Father': 144,
#  'First Keeper': 145,
#  'Second Keeper': 146,
#  'KING EDWARD IV': 147,
#  'CLARENCE': 148,
#  'LADY GREY': 149,
#  'Nobleman': 150,
#  'KING LEWIS XI': 151,
#  'OXFORD': 152,
#  'BONA': 153,
#  'HASTINGS': 154,
#  'QUEEN ELIZABETH': 155,
#  'First Watchman': 156,
#  'Second Watchman': 157,
#  'Third Watchman': 158,
#  'RIVERS': 159,
#  'Huntsman': 160,
#  'Lieutenant': 161,
#  'All': 162,
#  'First Messenger': 163,
#  'Second Messenger': 164,
#  'COUNTESS': 165,
#  'BERTRAM': 166,
#  'LAFEU': 167,
#  'HELENA': 168,
#  'PAROLLES': 169,
#  'Page': 170,
#  'KING': 171,
#  'First Lord': 172,
#  'Second Lord': 173,
#  'Steward': 174,
#  'Clown': 175,
#  'Both': 176,
#  'Fourth Lord': 177,
#  'DUKE': 178,
#  'Widow': 179,
#  'DIANA': 180,
#  'MARIANA': 181,
#  'Second Soldier': 182,
#  'Gentleman': 183,
#  'ORLANDO': 184,
#  'ADAM': 185,
#  'OLIVER': 186,
#  'DENNIS': 187,
#  'CELIA': 188,
#  'ROSALIND': 189,
#  'TOUCHSTONE': 190,
#  'LE BEAU': 191,
#  'DUKE FREDERICK': 192,
#  'DUKE SENIOR': 193,
#  'AMIENS': 194,
#  'CORIN': 195,
#  'SILVIUS': 196,
#  'JAQUES': 197,
#  'AUDREY': 198,
#  'SIR OLIVER MARTEXT': 199,
#  'PHEBE': 200,
#  'A Lord': 201,
#  'Forester': 202,
#  'WILLIAM': 203,
#  'First Page': 204,
#  'Second Page': 205,
#  'HYMEN': 206,
#  'JAQUES DE BOYS': 207,
#  'PHILO': 208,
#  'CLEOPATRA': 209,
#  'MARK ANTONY': 210,
#  'Attendant': 211,
#  'DEMETRIUS': 212,
#  'CHARMIAN': 213,
#  'ALEXAS': 214,
#  'Soothsayer': 215,
#  'DOMITIUS ENOBARBUS': 216,
#  'IRAS': 217,
#  'First Attendant': 218,
#  'Second Attendant': 219,
#  'OCTAVIUS CAESAR': 220,
#  'LEPIDUS': 221,
#  'MARDIAN': 222,
#  'POMPEY': 223,
#  'MENECRATES': 224,
#  'MENAS': 225,
#  'VARRIUS': 226,
#  'MECAENAS': 227,
#  'AGRIPPA': 228,
#  'OCTAVIA': 229,
#  'Attendants': 230,
#  'First Servant': 231,
#  'Second Servant': 232,
#  'VENTIDIUS': 233,
#  'SILIUS': 234,
#  'EROS': 235,
#  'CANIDIUS': 236,
#  'TAURUS': 237,
#  'SCARUS': 238,
#  'DOLABELLA': 239,
#  'EUPHRONIUS': 240,
#  'THYREUS': 241,
#  'Third Soldier': 242,
#  'Fourth Soldier': 243,
#  'First Guard': 244,
#  'Second Guard': 245,
#  'Third Guard': 246,
#  'DERCETAS': 247,
#  'DIOMEDES': 248,
#  'Egyptian': 249,
#  'PROCULEIUS': 250,
#  'GALLUS': 251,
#  'SELEUCUS': 252,
#  'Guard': 253,
#  'AEGEON': 254,
#  'DUKE SOLINUS': 255,
#  'Gaoler': 256,
#  'First Merchant': 257,
#  'OF SYRACUSE': 258,
#  'DROMIO OF SYRACUSE': 259,
#  'DROMIO OF EPHESUS': 260,
#  'ADRIANA': 261,
#  'LUCIANA': 262,
#  'OF EPHESUS': 263,
#  'BALTHAZAR': 264,
#  'LUCE': 265,
#  'ANTIPHOLUS': 266,
#  'ANGELO': 267,
#  'Second Merchant': 268,
#  'Courtezan': 269,
#  'PINCH': 270,
#  'AEMELIA': 271,
#  'Second Citizen': 272,
#  'MENENIUS': 273,
#  'MARCIUS': 274,
#  'First Senator': 275,
#  'COMINIUS': 276,
#  'TITUS': 277,
#  'SICINIUS': 278,
#  'BRUTUS': 279,
#  'AUFIDIUS': 280,
#  'Second Senator': 281,
#  'VOLUMNIA': 282,
#  'VIRGILIA': 283,
#  'Gentlewoman': 284,
#  'VALERIA': 285,
#  'LARTIUS': 286,
#  'First Roman': 287,
#  'Second Roman': 288,
#  'Third Roman': 289,
#  'CORIOLANUS': 290,
#  'First Officer': 291,
#  'Second Officer': 292,
#  'Senators': 293,
#  'Third Citizen': 294,
#  'Fourth Citizen': 295,
#  'Fifth Citizen': 296,
#  'Both Citizens': 297,
#  'Sixth Citizen': 298,
#  'Seventh Citizen': 299,
#  'All Citizens': 300,
#  'Citizens': 301,
#  'AEdile': 302,
#  'A Patrician': 303,
#  'Second Patrician': 304,
#  'Both Tribunes': 305,
#  'Roman': 306,
#  'Volsce': 307,
#  'Citizen': 308,
#  'First Servingman': 309,
#  'Second Servingman': 310,
#  'Third Servingman': 311,
#  'Young MARCIUS': 312,
#  'First Conspirator': 313,
#  'Second Conspirator': 314,
#  'Third Conspirator': 315,
#  'All The Lords': 316,
#  'Lords': 317,
#  'All Conspirators': 318,
#  'All The People': 319,
#  'Third Lord': 320,
#  'QUEEN': 321,
#  'POSTHUMUS LEONATUS': 322,
#  'IMOGEN': 323,
#  'CYMBELINE': 324,
#  'PISANIO': 325,
#  'CLOTEN': 326,
#  'Lady': 327,
#  'IACHIMO': 328,
#  'PHILARIO': 329,
#  'Frenchman': 330,
#  'First Lady': 331,
#  'CORNELIUS': 332,
#  'CAIUS LUCIUS': 333,
#  'BELARIUS': 334,
#  'GUIDERIUS': 335,
#  'ARVIRAGUS': 336,
#  'First Tribune': 337,
#  'Lord': 338,
#  'First Captain': 339,
#  'Second Captain': 340,
#  'Second Gaoler': 341,
#  'Sicilius Leonatus': 342,
#  'Mother': 343,
#  'First Brother': 344,
#  'Second Brother': 345,
#  'Jupiter': 346,
#  'Posthumus Leonatus': 347,
#  'BERNARDO': 348,
#  'FRANCISCO': 349,
#  'HORATIO': 350,
#  'MARCELLUS': 351,
#  'KING CLAUDIUS': 352,
#  'VOLTIMAND': 353,
#  'LAERTES': 354,
#  'LORD POLONIUS': 355,
#  'HAMLET': 356,
#  'QUEEN GERTRUDE': 357,
#  'OPHELIA': 358,
#  'Ghost': 359,
#  'REYNALDO': 360,
#  'ROSENCRANTZ': 361,
#  'GUILDENSTERN': 362,
#  'First Player': 363,
#  'Prologue': 364,
#  'Player King': 365,
#  'Player Queen': 366,
#  'LUCIANUS': 367,
#  'PRINCE FORTINBRAS': 368,
#  'Danes': 369,
#  'First Sailor': 370,
#  'First Clown': 371,
#  'Second Clown': 372,
#  'First Priest': 373,
#  'OSRIC': 374,
#  'First Ambassador': 375,
#  'Chorus': 376,
#  'CANTERBURY': 377,
#  'ELY': 378,
#  'KING HENRY V': 379,
#  'NYM': 380,
#  'PISTOL': 381,
#  'SCROOP': 382,
#  'CAMBRIDGE': 383,
#  'GREY': 384,
#  'KING OF FRANCE': 385,
#  'DAUPHIN': 386,
#  'Constable': 387,
#  'FLUELLEN': 388,
#  'GOWER': 389,
#  'JAMY': 390,
#  'MACMORRIS': 391,
#  'GOVERNOR': 392,
#  'KATHARINE': 393,
#  'ALICE': 394,
#  'BOURBON': 395,
#  'MONTJOY': 396,
#  'ORLEANS': 397,
#  'RAMBURES': 398,
#  'ERPINGHAM': 399,
#  'COURT': 400,
#  'BATES': 401,
#  'WILLIAMS': 402,
#  'GRANDPRE': 403,
#  'French Soldier': 404,
#  'QUEEN ISABEL': 405,
#  'FRENCH KING': 406,
#  'ABERGAVENNY': 407,
#  'CARDINAL WOLSEY': 408,
#  'First Secretary': 409,
#  'BRANDON': 410,
#  'KING HENRY VIII': 411,
#  'QUEEN KATHARINE': 412,
#  'Surveyor': 413,
#  'SANDS': 414,
#  'LOVELL': 415,
#  'GUILDFORD': 416,
#  'ANNE': 417,
#  'CARDINAL CAMPEIUS': 418,
#  'GARDINER': 419,
#  'Old Lady': 420,
#  'Scribe': 421,
#  'Crier': 422,
#  'GRIFFITH': 423,
#  'LINCOLN': 424,
#  'SURREY': 425,
#  'CROMWELL': 426,
#  'Third Gentleman': 427,
#  'PATIENCE': 428,
#  'CAPUCIUS': 429,
#  'DENNY': 430,
#  'CRANMER': 431,
#  'Keeper': 432,
#  'DOCTOR BUTTS': 433,
#  'Chancellor': 434,
#  'Man': 435,
#  'Garter': 436,
#  'KING JOHN': 437,
#  'CHATILLON': 438,
#  'QUEEN ELINOR': 439,
#  'ESSEX': 440,
#  'BASTARD': 441,
#  'ROBERT': 442,
#  'LADY FAULCONBRIDGE': 443,
#  'GURNEY': 444,
#  'LEWIS': 445,
#  'ARTHUR': 446,
#  'AUSTRIA': 447,
#  'CONSTANCE': 448,
#  'KING PHILIP': 449,
#  'BLANCH': 450,
#  'French Herald': 451,
#  'English Herald': 452,
#  'CARDINAL PANDULPH': 453,
#  'ELINOR': 454,
#  'HUBERT': 455,
#  'First Executioner': 456,
#  'PEMBROKE': 457,
#  'BIGOT': 458,
#  'MELUN': 459,
#  'FLAVIUS': 460,
#  'First Commoner': 461,
#  'MARULLUS': 462,
#  'Second Commoner': 463,
#  'CAESAR': 464,
#  'CASCA': 465,
#  'CALPURNIA': 466,
#  'ANTONY': 467,
#  'CASSIUS': 468,
#  'CICERO': 469,
#  'CINNA': 470,
#  'LUCIUS': 471,
#  'DECIUS BRUTUS': 472,
#  'METELLUS CIMBER': 473,
#  'TREBONIUS': 474,
#  'PORTIA': 475,
#  'LIGARIUS': 476,
#  'PUBLIUS': 477,
#  'ARTEMIDORUS': 478,
#  'POPILIUS': 479,
#  'Several Citizens': 480,
#  'CINNA THE POET': 481,
#  'OCTAVIUS': 482,
#  'LUCILIUS': 483,
#  'PINDARUS': 484,
#  'Poet': 485,
#  'MESSALA': 486,
#  'VARRO': 487,
#  'GHOST': 488,
#  'CLAUDIUS': 489,
#  'TITINIUS': 490,
#  'CATO': 491,
#  'CLITUS': 492,
#  'DARDANIUS': 493,
#  'VOLUMNIUS': 494,
#  'STRATO': 495,
#  'KENT': 496,
#  'EDMUND': 497,
#  'KING LEAR': 498,
#  'GONERIL': 499,
#  'CORDELIA': 500,
#  'LEAR': 501,
#  'REGAN': 502,
#  'CORNWALL': 503,
#  'EDGAR': 504,
#  'OSWALD': 505,
#  'Knight': 506,
#  'Fool': 507,
#  'ALBANY': 508,
#  'CURAN': 509,
#  'Third Servant': 510,
#  'Old Man': 511,
#  'Doctor': 512,
#  'FERDINAND': 513,
#  'LONGAVILLE': 514,
#  'DUMAIN': 515,
#  'BIRON': 516,
#  'DULL': 517,
#  'COSTARD': 518,
#  'ADRIANO DE ARMADO': 519,
#  'MOTH': 520,
#  'ARMADO': 521,
#  'JAQUENETTA': 522,
#  'BOYET': 523,
#  'PRINCESS': 524,
#  'MARIA': 525,
#  'ROSALINE': 526,
#  'SIR NATHANIEL': 527,
#  'HOLOFERNES': 528,
#  'MERCADE': 529,
#  'First Witch': 530,
#  'Second Witch': 531,
#  'Third Witch': 532,
#  'DUNCAN': 533,
#  'MALCOLM': 534,
#  'LENNOX': 535,
#  'ROSS': 536,
#  'MACBETH': 537,
#  'BANQUO': 538,
#  'ANGUS': 539,
#  'LADY MACBETH': 540,
#  'FLEANCE': 541,
#  'MACDUFF': 542,
#  'DONALBAIN': 543,
#  'ATTENDANT': 544,
#  'Both Murderers': 545,
#  'Third Murderer': 546,
#  'HECATE': 547,
#  'First Apparition': 548,
#  'Second Apparition': 549,
#  'Third Apparition': 550,
#  'LADY MACDUFF': 551,
#  'MENTEITH': 552,
#  'CAITHNESS': 553,
#  'SEYTON': 554,
#  'SIWARD': 555,
#  'Soldiers': 556,
#  'YOUNG SIWARD': 557,
#  'DUKE VINCENTIO': 558,
#  'ESCALUS': 559,
#  'LUCIO': 560,
#  'MISTRESS OVERDONE': 561,
#  'CLAUDIO': 562,
#  'Provost': 563,
#  'FRIAR THOMAS': 564,
#  'ISABELLA': 565,
#  'FRANCISCA': 566,
#  'ELBOW': 567,
#  'FROTH': 568,
#  'POMPHEY': 569,
#  'Justice': 570,
#  'JULIET': 571,
#  'ABHORSON': 572,
#  'BARNARDINE': 573,
#  'FRIAR PETER': 574,
#  'ANTONIO': 575,
#  'SALARINO': 576,
#  'SALANIO': 577,
#  'BASSANIO': 578,
#  'LORENZO': 579,
#  'GRATIANO': 580,
#  'NERISSA': 581,
#  'SHYLOCK': 582,
#  'MOROCCO': 583,
#  'LAUNCELOT': 584,
#  'GOBBO': 585,
#  'LEONARDO': 586,
#  'JESSICA': 587,
#  'ARRAGON': 588,
#  'TUBAL': 589,
#  'SALERIO': 590,
#  'BALTHASAR': 591,
#  'STEPHANO': 592,
#  'SHALLOW': 593,
#  'SLENDER': 594,
#  'SIR HUGH EVANS': 595,
#  'PAGE': 596,
#  'SIMPLE': 597,
#  'ANNE PAGE': 598,
#  'Host': 599,
#  'MISTRESS QUICKLY': 600,
#  'RUGBY': 601,
#  'DOCTOR CAIUS': 602,
#  'FENTON': 603,
#  'MISTRESS PAGE': 604,
#  'MISTRESS FORD': 605,
#  'FORD': 606,
#  'ROBIN': 607,
#  'WILLIAM PAGE': 608,
#  'THESEUS': 609,
#  'HIPPOLYTA': 610,
#  'EGEUS': 611,
#  'HERMIA': 612,
#  'LYSANDER': 613,
#  'QUINCE': 614,
#  'BOTTOM': 615,
#  'FLUTE': 616,
#  'STARVELING': 617,
#  'SNOUT': 618,
#  'SNUG': 619,
#  'PUCK': 620,
#  'Fairy': 621,
#  'OBERON': 622,
#  'TITANIA': 623,
#  'PEASEBLOSSOM': 624,
#  'COBWEB': 625,
#  'MUSTARDSEED': 626,
#  'HERNIA': 627,
#  'PHILOSTRATE': 628,
#  'Wall': 629,
#  'Pyramus': 630,
#  'Thisbe': 631,
#  'Lion': 632,
#  'Moonshine': 633,
#  'LEONATO': 634,
#  'BEATRICE': 635,
#  'HERO': 636,
#  'DON PEDRO': 637,
#  'BENEDICK': 638,
#  'DON JOHN': 639,
#  'CONRADE': 640,
#  'BORACHIO': 641,
#  'URSULA': 642,
#  'DOGBERRY': 643,
#  'VERGES': 644,
#  'Watchman': 645,
#  'FRIAR FRANCIS': 646,
#  'Sexton': 647,
#  'RODERIGO': 648,
#  'IAGO': 649,
#  'BRABANTIO': 650,
#  'OTHELLO': 651,
#  'CASSIO': 652,
#  'DUKE OF VENICE': 653,
#  'Sailor': 654,
#  'Senator': 655,
#  'DESDEMONA': 656,
#  'MONTANO': 657,
#  'Fourth Gentleman': 658,
#  'Second Gentlemen': 659,
#  'EMILIA': 660,
#  'First Musician': 661,
#  'BIANCA': 662,
#  'LODOVICO': 663,
#  'ANTIOCHUS': 664,
#  'PERICLES': 665,
#  'Daughter': 666,
#  'THALIARD': 667,
#  'HELICANUS': 668,
#  'CLEON': 669,
#  'DIONYZA': 670,
#  'First Fisherman': 671,
#  'Second Fisherman': 672,
#  'Third Fisherman': 673,
#  'SIMONIDES': 674,
#  'THAISA': 675,
#  'KNIGHTS': 676,
#  'Marshal': 677,
#  'First Knight': 678,
#  'Knights': 679,
#  'ESCANES': 680,
#  'Second Knight': 681,
#  'Third Knight': 682,
#  'LYCHORIDA': 683,
#  'Second Sailor': 684,
#  'CERIMON': 685,
#  'PHILEMON': 686,
#  'LEONINE': 687,
#  'MARINA': 688,
#  'First Pirate': 689,
#  'Second Pirate': 690,
#  'Third Pirate': 691,
#  'Pandar': 692,
#  'BOULT': 693,
#  'Bawd': 694,
#  'LYSIMACHUS': 695,
#  'Tyrian Sailor': 696,
#  'KING RICHARD II': 697,
#  'JOHN OF GAUNT': 698,
#  'HENRY BOLINGBROKE': 699,
#  'THOMAS MOWBRAY': 700,
#  'Lord Marshal': 701,
#  'DUKE OF AUMERLE': 702,
#  'First Herald': 703,
#  'Second Herald': 704,
#  'GREEN': 705,
#  'BUSHY': 706,
#  'DUKE OF YORK': 707,
#  'LORD ROSS': 708,
#  'LORD WILLOUGHBY': 709,
#  'BAGOT': 710,
#  'HENRY PERCY': 711,
#  'LORD BERKELEY': 712,
#  'EARL OF SALISBURY': 713,
#  'BISHOP OF CARLISLE': 714,
#  'SIR STEPHEN SCROOP': 715,
#  'Gardener': 716,
#  'GARDENER': 717,
#  'LORD FITZWATER': 718,
#  'DUKE OF SURREY': 719,
#  'Abbot': 720,
#  'DUCHESS OF YORK': 721,
#  'EXTON': 722,
#  'Groom': 723,
#  'BRAKENBURY': 724,
#  'LADY ANNE': 725,
#  'GENTLEMEN': 726,
#  'DERBY': 727,
#  'DORSET': 728,
#  'CATESBY': 729,
#  'Second murderer': 730,
#  'Girl': 731,
#  'Children': 732,
#  'Lord Mayor': 733,
#  'LORD STANLEY': 734,
#  'Pursuivant': 735,
#  'Priest': 736,
#  'RATCLIFF': 737,
#  'VAUGHAN': 738,
#  'BISHOP OF ELY': 739,
#  'LOVEL': 740,
#  'Scrivener': 741,
#  'ANOTHER': 742,
#  'KING RICHARD III': 743,
#  'TYRREL': 744,
#  'Third Messenger': 745,
#  'Fourth Messenger': 746,
#  'CHRISTOPHER': 747,
#  'RICHMOND': 748,
#  'HERBERT': 749,
#  'BLUNT': 750,
#  'of Prince Edward': 751,
#  'of King Henry VI': 752,
#  'Ghost of CLARENCE': 753,
#  'Ghost of RIVERS': 754,
#  'Ghost of GREY': 755,
#  'Ghost of VAUGHAN': 756,
#  'Ghost of HASTINGS': 757,
#  'of young Princes': 758,
#  'Ghost of LADY ANNE': 759,
#  'of BUCKINGHAM': 760,
#  'LORDS': 761,
#  'SAMPSON': 762,
#  'GREGORY': 763,
#  'ABRAHAM': 764,
#  'BENVOLIO': 765,
#  'TYBALT': 766,
#  'CAPULET': 767,
#  'LADY CAPULET': 768,
#  'LADY MONTAGUE': 769,
#  'ROMEO': 770,
#  'PARIS': 771,
#  'Nurse': 772,
#  'MERCUTIO': 773,
#  'Second Capulet': 774,
#  'FRIAR LAURENCE': 775,
#  'NURSE': 776,
#  'LADY  CAPULET': 777,
#  'Second Musician': 778,
#  'Musician': 779,
#  'Third Musician': 780,
#  'Apothecary': 781,
#  'FRIAR JOHN': 782,
#  'SLY': 783,
#  'First Huntsman': 784,
#  'Second Huntsman': 785,
#  'Players': 786,
#  'A Player': 787,
#  'LUCENTIO': 788,
#  'TRANIO': 789,
#  'BAPTISTA': 790,
#  'GREMIO': 791,
#  'KATHARINA': 792,
#  'HORTENSIO': 793,
#  'HORTENSIA': 794,
#  'BIONDELLO': 795,
#  'PETRUCHIO': 796,
#  'GRUMIO': 797,
#  'KATARINA': 798,
#  'CURTIS': 799,
#  'NATHANIEL': 800,
#  'PHILIP': 801,
#  'JOSEPH': 802,
#  'NICHOLAS': 803,
#  'Pedant': 804,
#  'Haberdasher': 805,
#  'Tailor': 806,
#  'VINCENTIO': 807,
#  'Boatswain': 808,
#  'ALONSO': 809,
#  'GONZALO': 810,
#  'SEBASTIAN': 811,
#  'Mariners': 812,
#  'MIRANDA': 813,
#  'PROSPERO': 814,
#  'ARIEL': 815,
#  'CALIBAN': 816,
#  'ADRIAN': 817,
#  'TRINCULO': 818,
#  'IRIS': 819,
#  'CERES': 820,
#  'JUNO': 821,
#  'Painter': 822,
#  'Merchant': 823,
#  'Jeweller': 824,
#  'TIMON': 825,
#  'Old Athenian': 826,
#  'APEMANTUS': 827,
#  'ALCIBIADES': 828,
#  'Cupid': 829,
#  'All Ladies': 830,
#  'All Lords': 831,
#  'CAPHIS': 832,
#  'All Servants': 833,
#  'FLAMINIUS': 834,
#  'LUCULLUS': 835,
#  'First Stranger': 836,
#  'Second Stranger': 837,
#  'SERVILIUS': 838,
#  'Third Stranger': 839,
#  'SEMPRONIUS': 840,
#  'HORTENSIUS': 841,
#  'PHILOTUS': 842,
#  'Third Senator': 843,
#  'Some Speak': 844,
#  'Some Others': 845,
#  'PHRYNIA': 846,
#  'TIMANDRA': 847,
#  'First Bandit': 848,
#  'Second Bandit': 849,
#  'Third Bandit': 850,
#  'Banditti': 851,
#  'SATURNINUS': 852,
#  'BASSIANUS': 853,
#  'MARCUS ANDRONICUS': 854,
#  'TITUS ANDRONICUS': 855,
#  'TAMORA': 856,
#  'CHIRON': 857,
#  'LAVINIA': 858,
#  'Tribunes': 859,
#  'MUTIUS': 860,
#  'MARTIUS': 861,
#  'QUINTUS': 862,
#  'AARON': 863,
#  'MARCUS': 864,
#  'Young LUCIUS': 865,
#  'AEMILIUS': 866,
#  'First Goth': 867,
#  'All the Goths': 868,
#  'Second Goth': 869,
#  'Third Goth': 870,
#  'TROILUS': 871,
#  'PANDARUS': 872,
#  'AENEAS': 873,
#  'CRESSIDA': 874,
#  'ALEXANDER': 875,
#  'AGAMEMNON': 876,
#  'NESTOR': 877,
#  'ULYSSES': 878,
#  'MENELAUS': 879,
#  'AJAX': 880,
#  'THERSITES': 881,
#  'ACHILLES': 882,
#  'PATROCLUS': 883,
#  'PRIAM': 884,
#  'HECTOR': 885,
#  'HELENUS': 886,
#  'CASSANDRA': 887,
#  'HELEN': 888,
#  'CALCHAS': 889,
#  'DEIPHOBUS': 890,
#  'ANDROMACHE': 891,
#  'MARGARELON': 892,
#  'MYRMIDONS': 893,
#  'DUKE ORSINO': 894,
#  'CURIO': 895,
#  'VALENTINE': 896,
#  'VIOLA': 897,
#  'SIR TOBY BELCH': 898,
#  'SIR ANDREW': 899,
#  'OLIVIA': 900,
#  'MALVOLIO': 901,
#  'FABIAN': 902,
#  'PROTEUS': 903,
#  'SPEED': 904,
#  'JULIA': 905,
#  'LUCETTA': 906,
#  'PANTHINO': 907,
#  'SILVIA': 908,
#  'LAUNCE': 909,
#  'THURIO': 910,
#  'First Outlaw': 911,
#  'Second Outlaw': 912,
#  'Third Outlaw': 913,
#  'EGLAMOUR': 914,
#  'Outlaws': 915,
#  'ARCHIDAMUS': 916,
#  'CAMILLO': 917,
#  'POLIXENES': 918,
#  'LEONTES': 919,
#  'HERMIONE': 920,
#  'MAMILLIUS': 921,
#  'Second Lady': 922,
#  'ANTIGONUS': 923,
#  'PAULINA': 924,
#  'CLEOMENES': 925,
#  'DION': 926,
#  'Mariner': 927,
#  'Time': 928,
#  'AUTOLYCUS': 929,
#  'FLORIZEL': 930,
#  'PERDITA': 931,
#  'DORCAS': 932,
#  'MOPSA': 933,
#  'Shepard': 934}

# %%
# Shows number of Players in Each Plays
import numpy as np

numberPlayers = spDF.groupby(['Play'])['Player'].nunique().sort_values(ascending= False).to_frame()
numberPlayers['Play'] = numberPlayers.index.tolist()
numberPlayers.columns = ['Num Players','Play']
numberPlayers.index= np.arange(0,len(numberPlayers))
numberPlayers

plt.figure(figsize=(10,10))
ax = sns.barplot(x='Num Players',y='Play',data=numberPlayers)
ax.set(xlabel='Number of Players', ylabel='Play Name')
plt.show()

# %%
# Convert Players to Labels
lbSPDF = spDF.replace({"Player": labPly})

# %%
# Feature Engineering
# Since Text cannot be used to classify, we find tfidf of all the playerlines
# Using this we will get the feature vectors, which then can be used to classify

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(lbSPDF.PlayerLine).toarray()
features.shape
# Out:
# (105153, 10568)

# %%
# Split Total Data into Train and Test
from sklearn.model_selection import train_test_split

lbSPDF = lbSPDF.dropna()

# one_hot_data = pd.get_dummies(lbSPDF.PlayerLine,drop_first=True,sparse=True)

#Player Line is the data and Player is the Classification

X_train, X_test, y_train, y_test = train_test_split(lbSPDF.PlayerLine, lbSPDF.Player, random_state=1)

# %%
# Classification using Naive Byes


from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# Run Training
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
# Run Testing and print accuracy
clf.score(count_vect.transform(X_test), y_test)
# Out:
# 0.0328654570352619

# %%
# Classification using 4 models
#   1)Random Forest 
#   2) Support Vector Machine
#   3)Naive Byes
#   4)Logistic Regression

# Cross Validation is used

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, lbSPDF.Player, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# C:\Users\kumar\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\kumar\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\kumar\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\kumar\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %%
# Accuracies after Classification using cross validation for all models
cv_df
# Out:
#                 model_name  fold_idx  accuracy
# 0   RandomForestClassifier         0  0.019356
# 1   RandomForestClassifier         1  0.021355
# 2   RandomForestClassifier         2  0.022505
# 3   RandomForestClassifier         3  0.022229
# 4   RandomForestClassifier         4  0.022854
# 5                LinearSVC         0  0.039692
# 6                LinearSVC         1  0.047659
# 7                LinearSVC         2  0.045485
# 8                LinearSVC         3  0.044553
# 9                LinearSVC         4  0.040430
# 10           MultinomialNB         0  0.030271
# 11           MultinomialNB         1  0.035309
# 12           MultinomialNB         2  0.032924
# 13           MultinomialNB         3  0.033895
# 14           MultinomialNB         4  0.032005
# 15      LogisticRegression         0  0.040812
# 16      LogisticRegression         1  0.051054
# 17      LogisticRegression         2  0.047436
# 18      LogisticRegression         3  0.048490
# 19      LogisticRegression         4  0.046434

# %%
# Average accuracy for each model
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.043564
# LogisticRegression        0.046845
# MultinomialNB             0.032881
# RandomForestClassifier    0.021660
# Name: accuracy, dtype: float64
